# %%
import cv2
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache using fc-list. This may take a moment.

# %%
# %matplotlib inline

# %%
test_img = cv2.imread("/Users/Banner/Documents/Portfolio/images/angular-plotly.png")

# %%
print(test_img.shape)
# Out:
# (256, 256, 3)

# %%
imgResize = cv2.resize(test_img, (128, 128))

# %%
print(imgResize.shape)
# Out:
# (128, 128, 3)

# %%
plt.imshow(imgResize)

# %%
plt.imshow(test_img)

# %%
imgCropped = test_img[0:100, 100:200]

# %%
plt.imshow(imgCropped)
